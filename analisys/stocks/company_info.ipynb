# %%
	
from yahoo_fin.stock_info import *
import yfinance as yf
import requests

def get_symbol(symbol):
    url = "http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={}&region=1&lang=en".format(symbol)

    result = requests.get(url).json()

    for x in result['ResultSet']['Result']:
        if x['symbol'] == symbol:
            return x['name']

# %%
TICKER = "AAPL"
get_symbol(TICKER)
# Out:
# 'Apple Inc.'

# %%
yfTicker = yf.Ticker(TICKER)
yfTicker.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 137000,
# ...

# %%
print("DOW JONES:")
print(tickers_dow())
#print("DOW NASDAQ:")
#print(tickers_nasdaq())
#print("SP500:")
#print(tickers_sp500())
# Out:
# DOW JONES:
# ['AAPL', 'AXP', 'BA', 'CAT', 'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PFE', 'PG', 'TRV', 'UNH', 'UTX', 'V', 'VZ', 'WBA', 'WMT', 'XOM']

# %%
print("MOST ACTIVE:")
print(get_day_most_active().head())
print("\n\nGAINERS:")
print(get_day_gainers().head())
print("\n\nLOOSES:")
print(get_day_losers().head())
print("\n\nTOP CRYPTO:")
print(get_top_crypto().head())
# Out:
# MOST ACTIVE:
#   Symbol                          Name  Price (Intraday)  Change  % Change  \
# 0      F            Ford Motor Company              5.09   -0.16     -2.95
# 1    BAC   Bank of America Corporation             21.70   -1.01     -4.47
# 2     GE      General Electric Company              7.57   -0.55     -6.77
# 3    CCL    Carnival Corporation & Plc             14.66   -3.16    -17.73
# 4    AMD  Advanced Micro Devices, Inc.             46.87   -0.63     -1.33
#
#        Volume  Avg Vol (3 month)   Market Cap  PE Ratio (TTM)
# 0  53428000.0         80846000.0   2.0201e+10          509.50
# 1  41428000.0         71235000.0  1.89371e+11            7.89
# 2  36671000.0         81538000.0   6.5858e+10             NaN
# 3  35091000.0         20509000.0   1.0411e+10            3.39
# 4  32601000.0         72422000.0   5.4822e+10          156.23
#
#
# GAINERS:
#    Symbol                            Name  Price (Intraday)  Change  % Change  \
# ...

# %%
get_stats(TICKER)
# Out:
#                                          Attribute         Value
# 0                          Market Cap (intraday) 5         1.09T
# 1                               Enterprise Value 3         1.14T
# 2                                     Trailing P/E         19.78
# 3                                    Forward P/E 1         16.30
# 4                      PEG Ratio (5 yr expected) 1          1.68
# 5                                Price/Sales (ttm)          4.07
# 6                                 Price/Book (mrq)         12.20
# 7                       Enterprise Value/Revenue 3          4.26
# 8                        Enterprise Value/EBITDA 6         14.60
# 9                                Beta (5Y Monthly)          1.29
# 10                                52-Week Change 3        36.06%
# 11                         S&P500 52-Week Change 3        -7.21%
# 12                                  52 Week High 3        327.85
# ...

# %%
get_analysts_info(TICKER)
# Out:
# {'Earnings Estimate':   Earnings Estimate  Current Qtr. (Mar 2020)  Next Qtr. (Jun 2020)  \
#  0   No. of Analysts                    31.00                 30.00
#  1     Avg. Estimate                     2.42                  2.24
#  2      Low Estimate                     1.73                  1.43
#  3     High Estimate                     3.10                  2.89
#  4      Year Ago EPS                     2.46                  2.18
#
#     Current Year (2020)  Next Year (2021)
#  0                39.00             38.00
#  1                12.92             15.28
#  2                10.86             13.36
#  3                14.37             16.98
#  4                11.89             12.92  ,
#  'Revenue Estimate':           Revenue Estimate Current Qtr. (Mar 2020) Next Qtr. (Jun 2020)  \
#  0          No. of Analysts                      27                   27
#  1            Avg. Estimate                  56.92B               54.37B
# ...

# %%
get_balance_sheet(TICKER)
# Out:
#                                      Breakdown  9/29/2019  9/29/2018  \
# 0                               Current Assets       None       None
# 1                                         Cash       None       None
# 2                    Cash And Cash Equivalents   48844000   25913000
# 3                       Short Term Investments   51713000   40388000
# 4                                   Total Cash  100557000   66301000
# 5                              Net Receivables   22926000   23186000
# 6                                    Inventory    4106000    3956000
# 7                         Other Current Assets   12352000   12087000
# 8                         Total Current Assets  162819000  131339000
# 9                           Non-current assets       None       None
# 10                Property plant and equipment       None       None
# 11          Gross property plant and equipment   95957000   90403000
# 12                    Accumulated Depreciation  -58579000  -49099000
# ...

# %%
get_income_statement(TICKER)
# Out:
#                                       Breakdown        ttm  9/29/2019  \
# 0                                 Total Revenue  267683000  260174000
# 1                               Cost of Revenue  166105000  161782000
# 2                                  Gross Profit  101578000   98392000
# 3                          Research Development   16766000   16217000
# 4            Selling General and Administrative   18659000   18245000
# 5                      Total Operating Expenses   35425000   34462000
# 6                      Operating Income or Loss   66153000   63930000
# 7                              Interest Expense    3471000    3576000
# 8               Total Other Income/Expenses Net     368000     422000
# 9                             Income Before Tax   67749000   65737000
# 10                           Income Tax Expense   10222000   10481000
# 11            Income from Continuing Operations   57527000   55256000
# ...

# %%
get_cash_flow(TICKER)
# Out:
#                                             Breakdown         ttm  9/29/2019  \
# 0                                          Net Income    57527000   55256000
# 1                         Depreciation & amortization    11968000   12547000
# 2                               Deferred income taxes     -742000    -340000
# 3                            Stock based compensation     6219000    6068000
# 4                           Change in working capital    -1015000   -3488000
# 5                                 Accounts receivable    -2870000     245000
# 6                                           Inventory      759000    -289000
# 7                                    Accounts Payable     5489000   -1923000
# 8                               Other working capital    63970000   58896000
# 9                                Other non-cash items     -740000    -652000
# 10           Net cash provided by operating activites    73217000   69391000
# ...

# %%
get_holders(TICKER)
# Out:
# {'Major Holders':     0.07%        % of Shares Held by All Insider
#  0  61.92%       % of Shares Held by Institutions
#  1  61.96%        % of Float Held by Institutions
#  2    4276  Number of Institutions Holding Shares,
#  'Direct Holders (Forms 3 and 4)':                               Holder     Shares Date Reported  % Out  \
#  0         Vanguard Group, Inc. (The)  329323432  Dec 30, 2019  7.53%
#  1                     Blackrock Inc.  277770570  Dec 30, 2019  6.35%
#  2            Berkshire Hathaway, Inc  245155566  Dec 30, 2019  5.60%
#  3           State Street Corporation  182854781  Dec 30, 2019  4.18%
#  4                           FMR, LLC   96342272  Dec 30, 2019  2.20%
#  5      Geode Capital Management, LLC   62482090  Dec 30, 2019  1.43%
#  6         Northern Trust Corporation   55032139  Dec 30, 2019  1.26%
#  7      Price (T.Rowe) Associates Inc   51779477  Dec 30, 2019  1.18%
#  8  Norges Bank Investment Management   46856273  Dec 30, 2019  1.07%
# ...

# %%
get_data(TICKER)
# Out:
#                   open        high         low       close    adjclose  \
# 1980-12-12    0.513393    0.515625    0.513393    0.513393    0.406782
# 1980-12-15    0.488839    0.488839    0.486607    0.486607    0.385558
# 1980-12-16    0.453125    0.453125    0.450893    0.450893    0.357260
# 1980-12-17    0.462054    0.464286    0.462054    0.462054    0.366103
# 1980-12-18    0.475446    0.477679    0.475446    0.475446    0.376715
# ...                ...         ...         ...         ...         ...
# 2020-03-23  228.080002  228.500000  212.610001  224.369995  224.369995
# 2020-03-24  236.360001  247.690002  234.300003  246.880005  246.880005
# 2020-03-25  250.750000  258.250000  244.300003  245.520004  245.520004
# 2020-03-26  246.520004  258.679993  246.360001  258.440002  258.440002
# 2020-03-27  252.750000  252.919998  248.380005  249.199997  249.199997
#
#                  volume ticker
# 1980-12-12  117258400.0   AAPL
# 1980-12-15   43971200.0   AAPL
# ...

# %%
get_quote_table(TICKER)
# Out:
# {'1y Target Est': 313.57,
#  '52 Week Range': '170.27 - 327.85',
#  'Ask': '250.60 x 800',
#  'Avg. Volume': 48614051.0,
#  'Beta (5Y Monthly)': 1.29,
#  'Bid': '250.54 x 800',
#  "Day's Range": '248.38 - 252.92',
#  'EPS (TTM)': 12.6,
#  'Earnings Date': 'Apr 27, 2020 - May 03, 2020',
#  'Ex-Dividend Date': 'Feb 06, 2020',
#  'Forward Dividend & Yield': '3.08 (1.19%)',
#  'Market Cap': '1.09T',
#  'Open': 252.75,
#  'PE Ratio (TTM)': 19.78,
#  'Previous Close': 258.44,
#  'Quote Price': 249.16990661621094,
#  'Volume': 19494564.0}

# %%
get_live_price(TICKER)
# Out:
# 249.29989624023438
